# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 82.3 MB/s eta 0:00:00
# ...

# %%
# Install pyngrok
# !pip install pyngrok

# Securely store your ngrok authtoken in Colab Secrets
# Go to the '🔑' icon on the left panel, click 'Add new secret',
# set 'Name' to 'NGROK_AUTH_TOKEN' and paste your token as 'Value'.
# Then, ensure 'Notebook access' is enabled.
from google.colab import userdata
import os

# Check if NGROK_AUTH_TOKEN is set in Colab Secrets
if 'NGROK_AUTH_TOKEN' not in os.environ:
    try:
        NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')
        os.environ['NGROK_AUTH_TOKEN'] = NGROK_AUTH_TOKEN
        print("ngrok authentication token retrieved from Colab Secrets.")
    except userdata.SecretError:
        print("NGROK_AUTH_TOKEN not found in Colab Secrets. Please add it.")
        print("You can get your auth token from https://ngrok.com/dashboard/your-authtoken")
else:
    print("NGROK_AUTH_TOKEN already set in environment variables.")
# Out:
# ...
# ngrok authentication token retrieved from Colab Secrets.

# %%
from pyngrok import ngrok
from google.colab import userdata
import os

# Terminate any existing ngrok tunnels if running
ngrok.kill()

# Ensure the ngrok authtoken is set explicitly
if 'NGROK_AUTH_TOKEN' not in os.environ:
    try:
        NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')
        os.environ['NGROK_AUTH_TOKEN'] = NGROK_AUTH_TOKEN
    except userdata.SecretError:
        print("NGROK_AUTH_TOKEN not found in Colab Secrets. Please add it.")
        print("You can get your auth token from https://ngrok.com/dashboard/your-authtoken")
        # Exit or raise an error if token is crucial and missing
        raise ValueError("ngrok authentication token is missing.")

ngrok.set_auth_token(os.environ['NGROK_AUTH_TOKEN'])

# Start Streamlit in the background
# !streamlit run /content/drive/MyDrive/Udemy_GenAI_with_LangChain_HuggingFace/ANN_Classification_Project/app.py --server.headless true --server.enableCORS false --server.enableXsrfProtection false &>/content/logs.txt &

# Create a public URL with ngrok for port 8501 (Streamlit's default port)
public_url = ngrok.connect(8501)
print(f"Your Streamlit app is available at: {public_url}")
# Out:
# Your Streamlit app is available at: NgrokTunnel: "https://trickily-tackiness-cornbread.ngrok-free.dev" -> "http://localhost:8501"
